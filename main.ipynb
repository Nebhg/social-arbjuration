# %%
# %pip install requests
# %pip install pandas
# %pip install pytrends
# %pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 KB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
# BeautifulSoup for parsing HTML
# selenium.webdriver for controlling the browser

# First, need to set up a Chromium WebDriver (install on Docker environment as I'm using WSL)
    # Ensure Chromium WebDriver is installed within your Docker container
    # This might involve adding a step in your Dockerfile to download and install the WebDriver

# Initialize the Selenium WebDriver for Chromium
    # Configure WebDriver options if necessary (e.g., headless mode, proxy settings)

# Open Google Trends and input the keyword
    # Use WebDriver to navigate to "https://trends.google.com/trends/"
    # Input the desired keyword into the search field and submit the form
    # Wait for the page to load completely, ensuring that dynamic content is fully rendered

# Extract HTML content from the page
    # Use WebDriver to get the page source after the keyword search results have loaded

# Locate the <div> element that contains the tabular data representation
    # This <div> has an aria-label "A tabular representation of the data in the chart."
    # It is hidden from view (style="position: absolute; left: -10000px;...")

# The table within that <div> follows this structure:
    # <table>
    #     <thead><tr><th>x</th><th>y1</th></tr></thead>
    #     <tbody>
    #         <tr><td>Timestamp</td><td>Interest Level</td></tr>
    #         ...
    #     </tbody>
    # </table>

# Use BeautifulSoup to parse the HTML content extracted from the page
    # Initialize a BeautifulSoup object with the page source

# Use BeautifulSoup to find the <div> by its aria-label
    # Within this <div>, find the <table> that contains the data

# Iterate over each row (<tr>) in the <tbody> of the table to extract the data
    # For each row, extract the timestamp from the first <td> and the interest level from the second <td>

# Store the extracted data in a suitable data structure (e.g., list of tuples)
    # Each tuple can contain the timestamp and the corresponding interest level

# Print the extracted data to test the output
    # Iterate over the stored data structure and print each entry

# Close the WebDriver session when done
    # This is important to free up resources and avoid leaving the browser open
